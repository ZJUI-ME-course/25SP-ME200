# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1
from sympy import *
m=S('m')
Wcycle=100e3 #kW


# 第一步 计算h1 h2 h3 h4
# 480K 8Mpa

h1=3348.4
s1=6.6586

# 0.08bar
sg=8.2287
sl=0.5926

hg=2577
hl=173.88

# print(h1)

x=(s1-sl)/(sg-sl)
h2=x*hg+(1-x)*hl

# print(h2)

h3=173.88
v3=1.0084e-3
p4=8e6
p3=8e3
h4=h3+v3*(p4-p3)/1e3

# print(h4)
# 第二步 

Wo=(h1-h2)*m
Wi=(h4-h3)*m
q1=(Wo-Wi)-Wcycle


# 第一种
m=solve(q1)[0]
# print('m',m) # kg


# 第二种
ht=h1-h2-h4+h3
# print('ht',ht)


Q=m*(h1-h4)
print('Q',Q)


Q2=m*(h2-h3)
############
eta=ht/(h1-h4)
print('eta',eta)


m2=Q2/(146.68-62.99)*3600
print(m2)
# Out:
# Q 251814.158502951
# eta 0.3971182581412636
# 6530421.44354909

# %%
# 2

# %%
document.querySelector('input[name="q_12"]').value = '-73.7';
document.querySelector('input[name="w_12"]').value = '-296.6';
document.querySelector('input[name="q_23"]').value = '45.33523089562982';
document.querySelector('input[name="w_23"]').value = '5.88523089562982';
document.querySelector('input[name="q_34"]').value = '0';
document.querySelector('input[name="w_34"]').value = '45.581080000000014';
document.querySelector('input[name="q_41"]').value = '-20.60692313437719';
document.querySelector('input[name="w_41"]').value = '-1.05979492308249';
document.querySelector('input[name="eta"]').value = '54.5422980896754';

# %%
# 3
#p511
