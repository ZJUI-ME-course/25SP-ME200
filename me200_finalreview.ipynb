# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1.4
1e3*3.14/2-49*9.81
# Out:
# 1089.31

# %% [markdown]
# 1 m = 39.3701 in
# 1 lbf/in**2 = 0.06894767 bar
# 1 lbf=4.44822 N
# 1 ft= 12 in
# 1 lbf =32.174 lb*ft/(s**2)

# %%
# 3.6

# %%
# 3.7

from sympy import *

L1 = 28 # cm
L2 = 21 # cm
T = 150 # degree centigrade

vg=0.3928
vl=1.095e-3

rate=L1/L2/(vg/vl)


x=1/(1/rate+1)

print(x*1e2)
# Out:
# 0.3703140059858977

# %%
# 7.1



m = 4.00;
w12=-2.5

h1=36.84
h2=270 

q2=w12-m*(h1-h2)
print(q2)


h3=(28-26.72)/(31.33-26.72)*(93.42-86.78)+86.78
h4=h3

q1=m*(h3-h2)
q3=m*(h4-h1)
print(q1,q2,q3)
# Out:
# 930.14
# -725.5054229934924 930.14 207.13457700650758
